# %% [markdown]
# <a href="https://colab.research.google.com/github/harinis8122006/Google-Collab/blob/main/Hiring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import linear_model

# Load data
df = pd.read_csv("hiring.csv")
df

# Train model
reg = linear_model.LinearRegression()
reg.fit(df[['experience', 'test_score', 'interview_score']], df.salary)

# Predict salary:
# 2 yr experience, 9 test score, 6 interview score
reg.predict(pd.DataFrame([[2, 9, 6]],
            columns=['experience', 'test_score', 'interview_score']))

# Predict salary:
# 12 yr experience, 10 test score, 10 interview score
reg.predict(pd.DataFrame([[12, 10, 10]],
            columns=['experience', 'test_score', 'interview_score']))
# Out:
# array([82781.64825828])

# %% [markdown]
# # New Section
